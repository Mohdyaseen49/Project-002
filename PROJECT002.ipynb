# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
yz = pd.read_csv('/content/drive/MyDrive/netflix_movies (1).csv')

# %%
yz.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
yz.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
yz.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
yz['director'].fillna(yz['director'].mode()[0], inplace=True)
yz['cast'].fillna(yz['cast'].mode()[0], inplace=True)
yz['country'].fillna(yz['country'].mode()[0], inplace=True)
yz['date_added'].fillna(yz['date_added'].mode()[0], inplace=True)
yz['rating'].fillna(yz['rating'].mode()[0], inplace=True)
yz['duration'].fillna(yz['duration'].mode()[0], inplace=True)

# %%
yz.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water    Rajiv Chilaka
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans    Rajiv Chilaka
# 4      s5  TV Show           Kota Factory    Rajiv Chilaka
#
#                                                 cast        country  \
# 0                                 David Attenborough  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                 David Attenborough  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
yz.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
# Find out which types of genre has most movies and TV Shows

most_common_genre = yz['listed_in'].str.split(', ').explode().mode()[0]

print(f"The most common genre is: {most_common_genre}")
# Out:
# The most common genre is: International Movies

# %%
#for visual representation using plots


plt.figure(figsize=(12, 6))
sns.histplot(x=genre_counts.index)
plt.xticks(rotation=90)
plt.title('Distribution of Genres')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.show()

# %%
# Get the top 10 countries contributing the most content
top_countries =yz['country'].value_counts().nlargest(10)

print(top_countries)
# Out:
# country
# United States     3649
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=yz, x='country') # Use 'country' as a string to refer to the column in ds
plt.xticks(rotation=90)
plt.title('top 10 countries contributing the most content')
plt.xlabel('Country') # Change xlabel to 'Country' for better clarity
plt.ylabel('Count')
plt.show()
